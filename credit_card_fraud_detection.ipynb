# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D://Sub//DATASETS//fraudTrain.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.drop(columns = 'Unnamed: 0',axis = 1,inplace = True)

# %%
df['is_fraud'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: is_fraud, dtype: int64

# %%
df.iloc[1:2,:].values
# Out:
# array([['2019-01-01 00:00:44', 630423337322,
#         'fraud_Heller, Gutmann and Zieme', 'grocery_pos', 107.23,
#         'Stephanie', 'Gill', 'F', '43039 Riley Greens Suite 393',
#         'Orient', 'WA', 99160, 48.8878, -118.2105, 149,
#         'Special educational needs teacher', '1978-06-21',
#         '1f76529f8574734946361c461b024d99', 1325376044, 49.159047,
#         -118.186462, 0]], dtype=object)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      lat      long  \
# 0                561 Perry Cove  Moravian Falls  ...  36.0788  -81.1781
# ...

# %% [markdown]
# **EDA**

# %%
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df['trans_date_trans_time'].dtype
# Out:
# dtype('O')

# %%
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
df['trans_date_trans_time']
# Out:
# 0         2019-01-01 00:00:18
# 1         2019-01-01 00:00:44
# 2         2019-01-01 00:00:51
# 3         2019-01-01 00:01:16
# 4         2019-01-01 00:03:06
#                   ...
# 1296670   2020-06-21 12:12:08
# 1296671   2020-06-21 12:12:19
# 1296672   2020-06-21 12:12:32
# 1296673   2020-06-21 12:13:36
# 1296674   2020-06-21 12:13:37
# Name: trans_date_trans_time, Length: 1296675, dtype: datetime64[ns]

# %%
df['dob'].dtype
# Out:
# dtype('O')

# %%
df['dob']
# Out:
# 0          1988-03-09
# 1          1978-06-21
# 2          1962-01-19
# 3          1967-01-12
# 4          1986-03-28
#               ...
# 1296670    1961-11-24
# 1296671    1979-12-11
# 1296672    1967-08-30
# 1296673    1980-08-18
# 1296674    1995-08-16
# Name: dob, Length: 1296675, dtype: object

# %%
df['dob'] = pd.to_datetime(df['dob'])
df['dob']
# Out:
# 0         1988-03-09
# 1         1978-06-21
# 2         1962-01-19
# 3         1967-01-12
# 4         1986-03-28
#              ...
# 1296670   1961-11-24
# 1296671   1979-12-11
# 1296672   1967-08-30
# 1296673   1980-08-18
# 1296674   1995-08-16
# Name: dob, Length: 1296675, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1296675 non-null  datetime64[ns]
#  1   cc_num                 1296675 non-null  int64
#  2   merchant               1296675 non-null  object
#  3   category               1296675 non-null  object
#  4   amt                    1296675 non-null  float64
#  5   first                  1296675 non-null  object
#  6   last                   1296675 non-null  object
#  7   gender                 1296675 non-null  object
#  8   street                 1296675 non-null  object
#  9   city                   1296675 non-null  object
#  10  state                  1296675 non-null  object
#  11  zip                    1296675 non-null  int64
#  12  lat                    1296675 non-null  float64
# ...

# %%
df.head(2)
# Out:
#   trans_date_trans_time            cc_num                         merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  fraud_Heller, Gutmann and Zieme
#
#       category     amt      first   last gender                        street  \
# 0     misc_net    4.97   Jennifer  Banks      F                561 Perry Cove
# 1  grocery_pos  107.23  Stephanie   Gill      F  43039 Riley Greens Suite 393
#
#              city  ...      lat      long  city_pop  \
# 0  Moravian Falls  ...  36.0788  -81.1781      3495
# 1          Orient  ...  48.8878 -118.2105       149
#
#                                  job        dob  \
# 0          Psychologist, counselling 1988-03-09
# 1  Special educational needs teacher 1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# ...

# %%
df['trans_month'] = df['trans_date_trans_time'].dt.month

# %%
df['trans_month']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1296670    6
# 1296671    6
# 1296672    6
# 1296673    6
# 1296674    6
# Name: trans_month, Length: 1296675, dtype: int32

# %%
df['trans_year'] = df['trans_date_trans_time'].dt.year

# %%
df['trans_day'] = df['trans_date_trans_time'].dt.day

# %%
df['Hour_of_Trans'] = df['trans_date_trans_time'].dt.hour

# %%
df['Hour_of_Trans']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 1296670    12
# 1296671    12
# 1296672    12
# 1296673    12
# 1296674    12
# Name: Hour_of_Trans, Length: 1296675, dtype: int32

# %%
from datetime import datetime

# %%
df['age'] = datetime.now().year - df['dob'].dt.year

# %%
df['age']
# Out:
# 0          37
# 1          47
# 2          63
# 3          58
# 4          39
#            ..
# 1296670    64
# 1296671    46
# 1296672    58
# 1296673    45
# 1296674    30
# Name: age, Length: 1296675, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1296675 non-null  datetime64[ns]
#  1   cc_num                 1296675 non-null  int64
#  2   merchant               1296675 non-null  object
#  3   category               1296675 non-null  object
#  4   amt                    1296675 non-null  float64
#  5   first                  1296675 non-null  object
#  6   last                   1296675 non-null  object
#  7   gender                 1296675 non-null  object
#  8   street                 1296675 non-null  object
#  9   city                   1296675 non-null  object
#  10  state                  1296675 non-null  object
#  11  zip                    1296675 non-null  int64
#  12  lat                    1296675 non-null  float64
# ...

# %%
df.head(2)
# Out:
#   trans_date_trans_time            cc_num                         merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  fraud_Heller, Gutmann and Zieme
#
#       category     amt      first   last gender                        street  \
# 0     misc_net    4.97   Jennifer  Banks      F                561 Perry Cove
# 1  grocery_pos  107.23  Stephanie   Gill      F  43039 Riley Greens Suite 393
#
#              city  ...                         trans_num   unix_time  \
# 0  Moravian Falls  ...  0b242abb623afc578575680df30655b9  1325376018
# 1          Orient  ...  1f76529f8574734946361c461b024d99  1325376044
#
#    merch_lat  merch_long  is_fraud trans_month trans_year trans_day  \
# 0  36.011293  -82.048315         0           1       2019         1
# 1  49.159047 -118.186462         0           1       2019         1
#
#    Hour_of_Trans  age
# 0              0   37
# 1              0   47
#
# ...

# %%
df['trans_day']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 1296670    21
# 1296671    21
# 1296672    21
# 1296673    21
# 1296674    21
# Name: trans_day, Length: 1296675, dtype: int32

# %%
df['col'] = df['trans_date_trans_time'].dt.weekday

# %%
df['trans_date_trans_time'].tail(4)
# Out:
# 1296671   2020-06-21 12:12:19
# 1296672   2020-06-21 12:12:32
# 1296673   2020-06-21 12:13:36
# 1296674   2020-06-21 12:13:37
# Name: trans_date_trans_time, dtype: datetime64[ns]

# %% [markdown]
# **Creating a Col Weekdays or Weekends**

# %%
df['Day_of_the_week'] = ['Weekday' if i <5 else 'Weekend' for i in df['col'] ]

# %%
df['col'].value_counts()
# Out:
# col
# 0    254282
# 6    250579
# 5    200957
# 1    160227
# 4    152272
# 3    147285
# 2    131073
# Name: count, dtype: int64

# %%
df['Day_of_the_week'].value_counts()
# Out:
# Day_of_the_week
# Weekday    845139
# Weekend    451536
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#   trans_date_trans_time            cc_num                         merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  fraud_Heller, Gutmann and Zieme
#
#       category     amt      first   last gender                        street  \
# 0     misc_net    4.97   Jennifer  Banks      F                561 Perry Cove
# 1  grocery_pos  107.23  Stephanie   Gill      F  43039 Riley Greens Suite 393
#
#              city  ...  merch_lat  merch_long  is_fraud  trans_month  \
# 0  Moravian Falls  ...  36.011293  -82.048315         0            1
# 1          Orient  ...  49.159047 -118.186462         0            1
#
#    trans_year trans_day Hour_of_Trans age  col  Day_of_the_week
# 0        2019         1             0  37    1          Weekday
# 1        2019         1             0  47    1          Weekday
#
# [2 rows x 29 columns]

# %% [markdown]
# - removing col which is helpful for creating weekdays and weekends

# %%
df.drop(columns = 'col',inplace = True)

# %% [markdown]
# - In the context of credit card fraud detection, outliers such as high transaction amounts or unusual patterns might actually carry critical information for identifying fraudulent activity. Removing or replacing them indiscriminately can lead to the loss of valuable insights

# %%
Q1 = df['amt'].quantile(0.25)
Q3 = df['amt'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Create a new feature 'is_outlier'
df['is_outlier'] = ((df['amt'] < lower_bound) | (df['amt'] > upper_bound)).astype(int)

# %%
df['is_outlier']   # checking either we have outliers or not
# Out:
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
#           ..
# 1296670    0
# 1296671    0
# 1296672    0
# 1296673    0
# 1296674    0
# Name: is_outlier, Length: 1296675, dtype: int32

# %%
sns.histplot(df['amt'],bins = 1000)
plt.show()

# %%
df['amt'].value_counts()
# Out:
# amt
# 1.14       542
# 1.04       538
# 1.25       535
# 1.02       533
# 1.01       523
#           ...
# 334.21       1
# 674.31       1
# 358.59       1
# 1159.68      1
# 255.52       1
# Name: count, Length: 52928, dtype: int64

# %%
fraud_outliers = df[(df['amt'] > upper_bound) & (df['is_fraud'] == 1)]
nonfraud_outliers = df[(df['amt'] > upper_bound) & (df['is_fraud'] == 0)]

print(f"Fraudulent outliers: {len(fraud_outliers)}")
print(f"Non-fraudulent outliers: {len(nonfraud_outliers)}")
# Out:
# Fraudulent outliers: 5705
# Non-fraudulent outliers: 61585

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...  merch_lat  merch_long  \
# 0                561 Perry Cove  Moravian Falls  ...  36.011293  -82.048315
# ...

# %% [markdown]
# **One hot Encoder**
# - where categorical varibles doesnt have order

# %%
from sklearn.preprocessing import OneHotEncoder

oe = OneHotEncoder(sparse_output = False)

# %%
'''
for i in df.select_dtypes(include = 'object').columns :
    
    df[i] = oe.fit_transform(df[[i]])

'''
# Out:
# "\nfor i in df.select_dtypes(include = 'object').columns :\n    \n    df[i] = oe.fit_transform(df[[i]])\n\n"

# %% [markdown]
# - The error you're encountering suggests that you're trying to allocate a large array (approximately 4.65 GiB) for one-hot encoding a DataFrame with a large number of rows and columns. When applying one-hot encoding to a dataset with many unique categories, it can lead to a memory overflow because the resulting matrix will become very large, especially if the categorical columns have many unique values

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Apply LabelEncoder to each categorical column
for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head(2)
# Out:
#   trans_date_trans_time            cc_num  merchant  category     amt  first  \
# 0   2019-01-01 00:00:18  2703186189652095       514         8    4.97    162
# 1   2019-01-01 00:00:44      630423337322       241         4  107.23    309
#
#    last  gender  street  city  ...  merch_lat  merch_long  is_fraud  \
# 0    18       0     568   526  ...  36.011293  -82.048315         0
# 1   157       0     435   612  ...  49.159047 -118.186462         0
#
#    trans_month  trans_year  trans_day Hour_of_Trans  age  Day_of_the_week  \
# 0            1        2019          1             0   37                0
# 1            1        2019          1             0   47                0
#
#    is_outlier
# 0           0
# 1           0
#
# [2 rows x 29 columns]

# %%
df.drop(columns = 'trans_date_trans_time',axis = 1,inplace = True)

# %% [markdown]
# **spliting the data**

# %%
x = df.drop(columns = 'is_fraud')
y = df['is_fraud']

# %%
x
# Out:
#                       cc_num  merchant  category     amt  first  last  gender  \
# 0           2703186189652095       514         8    4.97    162    18       0
# 1               630423337322       241         4  107.23    309   157       0
# 2             38859492057661       390         0  220.11    115   381       1
# 3           3534093764340240       360         2   45.00    163   463       1
# 4            375534208663984       297         9   41.96    336   149       1
# ...                      ...       ...       ...     ...    ...   ...     ...
# 1296670       30263540414123       499         0   15.56    121   332       1
# 1296671     6011149206456997         2         1   51.70    160   463       1
# 1296672     3514865930894695       599         1  105.93     74    67       1
# 1296673     2720012583106919       509         1   74.90    179   304       1
# 1296674  4292902571056973207       370         1    4.30    160   404       1
#
# ...

# %% [markdown]
# **StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

# %%
for i in x.select_dtypes(include = 'datetime64[ns]').columns :
    x[i] = x[i].astype('int64')

# %%
x_scaled = ss.fit_transform(x)
x_scaled
# Out:
# array([[-1.8518249 , -0.31669237,  0.85165441, ..., -0.848322  ,
#         -0.73094066, -0.23395445],
#        [-1.85182288, -0.31875727, -0.50688018, ..., -0.27289762,
#         -0.73094066, -0.23395445],
#        [-1.85182233, -0.31872806,  0.23459108, ...,  0.64778139,
#         -0.73094066,  4.27433632],
#        ...,
#        [ 1.76070971, -0.3160722 ,  1.27464137, ...,  0.3600692 ,
#          1.36810012, -0.23395445],
#        [ 1.76071469, -0.31667951,  0.82677283, ..., -0.3879825 ,
#          1.36810012, -0.23395445],
#        [ 1.76071477,  2.96125682,  0.13506474, ..., -1.25111907,
#          1.36810012, -0.23395445]])

# %%
new_x = pd.DataFrame(x_scaled,columns = x.columns)
new_x
# Out:
#          trans_date_trans_time    cc_num  merchant  category       amt  \
# 0                    -1.851825 -0.316692  0.851654  0.452853 -0.407826
# 1                    -1.851823 -0.318757 -0.506880 -0.569266  0.230039
# 2                    -1.851822 -0.318728  0.234591 -1.591384  0.934149
# 3                    -1.851820 -0.316058  0.085302 -1.080325 -0.158132
# 4                    -1.851812 -0.318471 -0.228206  0.708382 -0.177094
# ...                        ...       ...       ...       ...       ...
# 1296670               1.760708 -0.318735  0.777010 -1.591384 -0.341769
# 1296671               1.760709 -0.314165 -1.696220 -1.335854 -0.116339
# 1296672               1.760710 -0.316072  1.274641 -1.335854  0.221930
# 1296673               1.760715 -0.316680  0.826773 -1.335854  0.028375
# 1296674               1.760715  2.961257  0.135065 -1.335854 -0.412005
#
#             first      last    gender    street      city  ...  unix_time  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, r2_score
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(new_x, y, test_size=0.3, random_state=42)

smote = SMOTE(sampling_strategy='auto', random_state=42)  # You can adjust 'sampling_strategy'
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
model = RandomForestClassifier(n_estimators= 50)

# %%
# Train the model
model.fit(X_train_smote, y_train_smote)
    
# Make predictions
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

r2 = r2_score(y_test, y_pred) 
    
    
    
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"R² Score: {r2:.4f}")
print('-' * 60)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print('-' * 60)
# Out:
# Accuracy: 0.9985
# Precision: 0.9247
# Recall: 0.8066
# F1-Score: 0.8616
# R² Score: 0.7394
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    386718
#            1       0.92      0.81      0.86      2285
#
#     accuracy                           1.00    389003
#    macro avg       0.96      0.90      0.93    389003
# weighted avg       1.00      1.00      1.00    389003
#
# [[386568    150]
#  [   442   1843]]
# ------------------------------------------------------------

# %%
'''
# Import necessary libraries
from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, r2_score


# Train-test split
X_train, X_test, y_train, y_test = train_test_split(new_x, y, test_size=0.3, random_state=42)

smote = SMOTE(sampling_strategy='auto', random_state=42)  # You can adjust 'sampling_strategy'
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)


# List of models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators= 50),
    'Gradient Boosting': GradientBoostingClassifier(),
    'SVM': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB()
}

# Train and evaluate each model
for model_name, model in models.items():
    print(f"Training {model_name}...")
    
    # Train the model
    model.fit(X_train_smote, y_train_smote)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    
    # Calculate metrics
    print(f"\n{model_name} Performance:")
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    r2 = r2_score(y_test, y_pred) 
    
    
    
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"R² Score: {r2:.4f}")
    print('-' * 60)
    
    # Print evaluation metrics
    print(f"\n{model_name} Performance:")
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    print('-' * 60)
'''
# Out:
# '\n# Import necessary libraries\nfrom imblearn.over_sampling import SMOTE\n\nfrom sklearn.linear_model import LogisticRegression\nfrom sklearn.tree import DecisionTreeClassifier\nfrom sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier\nfrom sklearn.svm import SVC\nfrom sklearn.neighbors import KNeighborsClassifier\nfrom sklearn.naive_bayes import GaussianNB\nfrom sklearn.metrics import classification_report, confusion_matrix,accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, r2_score\n\n\n# Train-test split\nX_train, X_test, y_train, y_test = train_test_split(new_x, y, test_size=0.3, random_state=42)\n\nsmote = SMOTE(sampling_strategy=\'auto\', random_state=42)  # You can adjust \'sampling_strategy\'\nX_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)\n\n\n# List of models\nmodels = {\n    \'Logistic Regression\': LogisticRegression(),\n    \'Decision Tree\': DecisionTreeClassifier(),\n    \'Random Forest\': RandomForestCl
# ...
